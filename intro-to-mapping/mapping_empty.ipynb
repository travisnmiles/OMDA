# %% [markdown]
# # Mapping in Python
# Now that we have the basics down from last week's lab, we can learn how to create maps using python. In oceanography, we frequently deal with maps to convey spatial data like fields of sea surface temperature or wind speed. Below is an example of what you can do with mapping in Python from Sam Coakley's Masters Thesis. The map shows the East China Sea with the depth of the water in color, the change in sea surface temperature of the last few days as contours, and the path of a tropical cyclone plotted as a line across the map. Mapping is a valuable tool because can give a science story context.

# %% [markdown]
# <img src="soulik_map.png" width=400 height=400 />

# %% [markdown]
# We will be using a few new packages today to work with new data sets and to build maps! So we can install these new packages below. As with last class, you only need to run this cell once so you can comment it out with ### after you run it

# %%
# Install necessary packages

# import sys
# !conda install --yes --prefix {sys.prefix} pandas
# !conda install --yes --prefix {sys.prefix} cartopy

# %% [markdown]
# It is the 'best practice' in python to do all of your pacakge importing at the top of your notebook

# %%
# %matplotlib inline 
# This is a magic function that lets jupyter know we are going to plot in this notebook

# Import the necessary packages
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
import cartopy.feature as cfeature
import pandas as pd
import numpy as np
import xarray as xr

# %%
import cartopy
import cartopy.crs as ccrs  # commonly used shorthand
import cartopy.feature as cfeature

# %% [markdown]
# We are going to use `cartopy` to make our maps and `pandas` to deal with tabular data.

# %% [markdown]
# # Mapping Basics

# %% [markdown]
# Today, we are going to plot maps in python using cartopy. This is different than making a regular plot in python because we have to let matplotlib know that we are working with geographical data which we do by making a GeoAxes and assigning our plotting area a projection. A projection is the method used to 'flatten' our spherical planet into a 2D plot.

# %%
#Step 1: Open a figure and save the figure object into a variable.
fig = plt.figure() 

#step 2: Add the axes to the figure object you created.
ax = fig.add_subplot(projection=ccrs.PlateCarree()) # Creates an axes and tells matplotlib that we want it to be a map

ax # prints the axis to the screen
# Out:
# <GeoAxesSubplot:>

# %% [markdown]
# If everything worked, you should have a very boring box but the text above the very boring box tells us that matplotlib knows that we are dealing with a map. Here we have the most basic projection: plate carrée, which is an equirectangular projection, and is essentially equivalent to just plotting the longitude and latitude values without a projection. I will refer to longitude and latitude as "geographic coordinates".

# %% [markdown]
# Now `ax` is a Cartopy object and contains all the features of cartopy.
# Let's try to make this box a little more interesting.

# %%
fig = plt.figure()

ax = fig.add_subplot(projection=ccrs.PlateCarree())

ax.coastlines(resolution='110m') # coastline resolution options are '110m', '50m', '10m'

ax.gridlines()

# %% [markdown]
# `ax.coastlines()` tells python to plot the stock coastline information onto the map. `cartopy` has a lot of features like this where we can add details to our map without having to go through the trouble of loading data

# %% [markdown]
# ### Useful methods of a GeoAxes
# The GeoAxes class adds a number of useful methods.
#
# Let's take a look at:
#
# - `set_global` - zoom the map out as much as possible
# - `set_extent` - zoom the map to the given bounding box
# - `gridlines` - add a graticule (and optionally labels) to the axes
# - `coastlines` - add Natural Earth coastlines to the axes
# - `stock_img` - add a low-resolution Natural Earth background image to the axes
# - `imshow` - add an image (numpy array) to the axes
# - `add_geometries` - add a collection of geometries (Shapely) to the axes

# %% [markdown]
# Now let's add a stock image and gridlines

# %%
fig = plt.figure()
ax = fig.add_subplot(projection=ccrs.PlateCarree())
ax.coastlines()
ax.gridlines()
ax.stock_img()

# %% [markdown]
# ### What is Projection:
# When creating a map or geographical plot, we need to choose a way to represent the 3D surface of the Earth on a 2D plane, like a piece of paper or a computer screen. This method of representation is called a "projection." Each projection has its own way of translating the Earth's surface to a flat map, and each comes with its own set of compromises in terms of accuracy, area, shape, and direction.
#
# Steps involves:
# 1. You choose a projection for your map when you set it up. This projection defines how the 3D world looks on your 2D plot.
# 2. You can plot data that comes in any projection (or even unprojected data), but you need to specify its original projection so the plotting library can accurately display it on your chosen map projection.

# %% [markdown]
#  cartopy provides a number of projections. Available projections are:
#
# 1. PlateCarree
# 2. AlbersEqualArea
# 3. AzimuthalEquidistant
# 4. LambertConformal
# 5. LambertCylindrical
# 6. Mercator
# 7. Miller
# 8. Mollweide
# 9. Orthographic
# 10. Robinson
# 11. Sinusoidal
# 12. Stereographic
# 13. TransverseMercator
# 14. UTM
# 15. InterruptedGoodeHomolosine
# 16. RotatedPole
# 17. OSGB
# 18. EuroPP
# 19. Geostationary
# 20. Gnomonic
# 21. LambertAzimuthalEqualArea
# 22. NorthPolarStereo
# 23. OSNI
# 24. SouthPolarStereo

# %% [markdown]
# # Plotting points on a map
# We can add data to the maps by using some familiar commands from matplotlib.
# We will be using a new type of data structure. Last week we used `numpy` and `pandas`'s to load in and manipulate data.
# Today we will again use `pandas` to load in a `.csv` as a pandas `DataFrame`. The `DataFrame` data structure has `keys` for each column that tell you about what the column represents.
# Let's see how this works below with a `.csv` of a RU locations across New Jersey.

# %%
labs = pd.read_csv('RU lab coordinates.csv') # this pandas function already knows what the delimiter is!


print(labs.keys())
print(type(labs))
labs
# Out:
# Index(['Location', 'Abbrev.', 'Latitude', 'Longitude'], dtype='object')
# <class 'pandas.core.frame.DataFrame'>
#                          Location Abbrev.   Latitude  Longitude
# 0                      Haskin Lab    HSRL  39.233933 -75.031133
# 1                  Cape Shore Lab      CS  39.073667 -74.912633
# 2   Aquaculture Innovation Center     AIC  38.969493 -74.941066
# 3  Fisheries Collaborative Center     FCC  38.945404 -74.898538
# 4           Jacques Cousteau NERR  JCNERR  39.594702 -74.346575
# 5            Marine Field Station   RUMFS  39.508947 -74.324152
# 6          Rutgers Passion Puddle    RUPP  40.482465 -74.437177
# 7                   Morgan Marina      MM  40.455206 -74.272124
# 8                  Crew Boathouse    CREW  40.487886 -74.433386

# %% [markdown]
# From `print(labs)` we can see that each column has a header (aka `key`) that tells us what the data in the column is. All the way on the left, we can see the index of each of the entries in each column.
#
# The `DataFrame` allows us to load in a `.csv` that contains data of many `types`. In the `Location` column, the data are strings. In the `Latitude` column, the data are numbers (aka `floats`).

# %%
labs['Latitude'], labs['Longitude'] # to see all the data under one column or key of a dataframe
# Out:
# (0    39.233933
#  1    39.073667
#  2    38.969493
#  3    38.945404
#  4    39.594702
#  5    39.508947
#  6    40.482465
#  7    40.455206
#  8    40.487886
#  Name: Latitude, dtype: float64,
#  0   -75.031133
#  1   -74.912633
#  2   -74.941066
#  3   -74.898538
#  4   -74.346575
#  5   -74.324152
#  6   -74.437177
#  7   -74.272124
#  8   -74.433386
#  Name: Longitude, dtype: float64)

# %%
labs['Location'][0] # To pull out one data point using the index of the data frame that appears on the left of our data.
# Out:
# 'Haskin Lab'

# %%
labs['Abbrev.'][1:] # we can still slice just like in numpy arrays
# Out:
# 1        CS
# 2       AIC
# 3       FCC
# 4    JCNERR
# 5     RUMFS
# 6      RUPP
# 7        MM
# 8      CREW
# Name: Abbrev., dtype: object

# %% [markdown]
# **Splendid! Now let's add some data to our plot. All we need to do is use `scatter` to add dots!**

# %%
# Create a space to make the plot
fig = plt.figure()
ax = fig.add_subplot(projection = ccrs.PlateCarree())
ax.scatter(labs['Longitude'], labs['Latitude'], s=120, c='green',edgecolor='black'); # Plots the individual points on the map
ax.set_xlabel('Longitude')
ax.set_ylabel('Latitude')
# Out:
# Text(0, 0.5, 'Latitude')

# %% [markdown]
# Wow those sure are green dots! This still doesn't look much like a map so we need to add some features from `cartopy`

# %%
fig = plt.figure(figsize=(5,6))
ax = plt.axes(projection = ccrs.PlateCarree())

# add geographic information
ax.add_feature(cartopy.feature.OCEAN)
ax.add_feature(cfeature.LAND, edgecolor='black')
ax.add_feature(cfeature.COASTLINE, edgecolor='black')
ax.add_feature(cfeature.STATES, edgecolor='black')

ax.scatter(labs['Longitude'], labs['Latitude'], s=175, c='green',edgecolor='black'); # Plots the individual points on the map

# %% [markdown]
# Ok cool! Now we can tell that some points are on the coastline while others are further inshore. I want to zoom out a bit to get a better view of New Jersey but first we need to add x and y information on the axes so we know how far to zoom out

# %%
# Define some geographic locations as (longitude, latitude) pairs
animal_locations = [(-74, 40),  # New York
                    (10, 50),   # Germany
                    (143, -38), # Australia
                    (-58, -34)] # Argentina

# Convert our list to separate lists of longitudes and latitudes for plotting
lons, lats = zip(*animal_locations)

fig, axs = plt.subplots(1, 2, figsize=(14, 7),
                        subplot_kw={'projection': ccrs.PlateCarree()},
                        gridspec_kw={'width_ratios': [1, 1], 'wspace': 0.4})

# Projection 1: PlateCarree (equidistant cylindrical)
axs[0].set_global()
axs[0].coastlines()
axs[0].plot(lons, lats, 'ro', transform=ccrs.Geodetic())
axs[0].set_title('PlateCarree Projection')

# Projection 2: Mollweide
axs[1] = plt.subplot(1, 2, 2, projection=ccrs.Mollweide())
axs[1].set_global()
axs[1].coastlines()
axs[1].plot(lons, lats, 'ro', transform=ccrs.Geodetic())
axs[1].set_title('Mollweide Projection')

plt.show()

# %%
fig = plt.figure(figsize=(4,6))
ax = plt.axes(projection = ccrs.PlateCarree())


ax.add_feature(cfeature.OCEAN)
ax.add_feature(cfeature.LAND, edgecolor='black')
ax.add_feature(cfeature.COASTLINE, edgecolor='black')
ax.add_feature(cfeature.STATES, edgecolor='black')

# Plots the individual points on the map
ax.scatter(labs['Longitude'], labs['Latitude'], s=175, c='green',edgecolor='black'); 

# Also, let's add a title and some information to our axis
plt.title('Key locations for OMDA')

# let's provide the spatial context to the figure
gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True, color='gray', alpha=0.3) # adds grid lines to the plot
# gl.top_labels = False # turn off the axis labels on the top of the plot
# gl.right_labels = False # turn off the axis labels on the right of the plot
gl.xformatter = LONGITUDE_FORMATTER # these let matplotlib know that the x and y axis are longitude and latitude data and to add °W °N
gl.yformatter = LATITUDE_FORMATTER

# %% [markdown]
# In summary, while `ax.set_xlabel()` and `ax.set_ylabel()` are suitable for labeling the axes in standard plots, geographic plots created with Cartopy use `gl.xformatter` and `gl.yformatter` within the Gridliner object to format gridline labels for longitude and latitude. This approach is tailored to the specific needs of representing geographic information on maps.

# %% [markdown]
# Now we can see where we are with the Lat/Lon but let's zoom out a little to provide more spatial context using `ax.set_extent`

# %%
fig = plt.figure(figsize=(4,6))
ax = plt.axes(projection = ccrs.PlateCarree())
ax.add_feature(cfeature.OCEAN)
ax.add_feature(cfeature.LAND, edgecolor='black')
ax.add_feature(cfeature.COASTLINE, edgecolor='black')
ax.add_feature(cfeature.STATES, edgecolor='black')

# Plots the individual points on the map
ax.scatter(labs['Longitude'], labs['Latitude'], s=175, c='green',edgecolor='black'); # Plots the individual points on the map

# Also, let's add a title and some information to our axes
plt.title('Key locations for OMDA')
gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True, color='gray', alpha=0.3)
gl.top_labels = False
gl.right_labels = False
gl.xformatter = LONGITUDE_FORMATTER
gl.yformatter = LATITUDE_FORMATTER

# We can set the x and y limits of the plot using ax.set_extent
# This can be used to zoom in and out of particular areas of the map
lon1 = -75.75
lon2 = -73.8
lat1 = 41.5
lat2 = 38.5
extent=[lon1, lon2, lat1, lat2] # Play with this to zoom out enough to provide context
ax.set_extent(extent)

# %% [markdown]
# I want to mark Passion Puddle with a Scarlet marker because go knights and I will add a legend to the map to let everyone else know what the red dot means.

# %%
print(labs) # Passion Puddle is at index 6
# Out:
#                          Location Abbrev.   Latitude  Longitude
# 0                      Haskin Lab    HSRL  39.233933 -75.031133
# 1                  Cape Shore Lab      CS  39.073667 -74.912633
# 2   Aquaculture Innovation Center     AIC  38.969493 -74.941066
# 3  Fisheries Collaborative Center     FCC  38.945404 -74.898538
# 4           Jacques Cousteau NERR  JCNERR  39.594702 -74.346575
# 5            Marine Field Station   RUMFS  39.508947 -74.324152
# 6          Rutgers Passion Puddle    RUPP  40.482465 -74.437177
# 7                   Morgan Marina      MM  40.455206 -74.272124
# 8                  Crew Boathouse    CREW  40.487886 -74.433386

# %% [markdown]
# ### Brief Protip:
# If our data set was thousands of points long, using `print(labs)` would spit out a lot of information and that would not really help us find the index. Below is a good method for finding a matching value.
# `np.where` returns a list of indices where the value on the right of the `==` matches exactly with a value in the array on the left

# %%
print(np.where(labs['Location'] == 'Rutgers Passion Puddle')[0])
# Out:
# [6]

# %% [markdown]
# ### End Protip

# %% [markdown]
# Passion Puddle is at index 6 so we can add another `scatter` command to plot just that one value in its own color and to give it a label

# %%
fig = plt.figure(figsize=(4,6))
ax = plt.axes(projection = ccrs.PlateCarree())
ax.add_feature(cfeature.OCEAN)
ax.add_feature(cfeature.LAND, edgecolor='black')
ax.add_feature(cfeature.COASTLINE, edgecolor='black')
ax.add_feature(cfeature.STATES, edgecolor='black')

ax.scatter(labs['Longitude'], labs['Latitude'], s=175, c='green',edgecolor='black'); # Plots the individual points on the map

# Plots just one point and gives it a label based on the Location column
ax.scatter(labs['Longitude'][6], labs['Latitude'][6], s=175, c='red',edgecolor='black', label=labs['Location'][6]); 

# adds a legend to the map
plt.legend()


# Also, let's add a title and some information to our axes
plt.title('Key locations for OMDA')
gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True, color='gray', alpha=0.3)
gl.top_labels = False
gl.right_labels = False
gl.xformatter = LONGITUDE_FORMATTER
gl.yformatter = LATITUDE_FORMATTER

# We can set the x and y limits of the plot using ax.set_extent
# This can be used to zoom in and out of particular areas of the map
lon1 = -75.75
lon2 = -73.8
lat1 = 41.5
lat2 = 38.5
extent=[lon1, lon2, lat1, lat2] # Play with this to zoom out enough to provide context
ax.set_extent(extent)

# %% [markdown]
# Finally, we can play with the projection of the map by changing `ccrs.PlateCarree()` to `ccrs.Sinusoidal()`. However, when we do that, we need to change our scatter command by adding a keyword argument `transform`. We use `transform` to tell python what coordinate system our data is defined in.

# %%
fig = plt.figure(figsize=(4,6))
ax = plt.axes(projection = ccrs.LambertConformal())
ax.add_feature(cfeature.OCEAN)
ax.add_feature(cfeature.LAND, edgecolor='black')
ax.add_feature(cfeature.COASTLINE, edgecolor='black')
ax.add_feature(cfeature.STATES, edgecolor='black')

ax.scatter(labs['Longitude'], labs['Latitude'], s=175, c='green',edgecolor='black', transform=ccrs.PlateCarree()); # Plots the individual points on the map

# Plots just one point and gives it a label based on the Location column
ax.scatter(labs['Longitude'][6], labs['Latitude'][6], s=60, c='red',edgecolor='black', label=labs['Location'][6], transform=ccrs.PlateCarree()); 
# ax.set_global()
plt.legend() # adds a legend to the map


# Also, let's add a title and some information to our axis
plt.title('Key locations for OMDA')
gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True, color='gray', alpha=0.3)
gl.top_labels = False
gl.right_labels = False
gl.xformatter = LONGITUDE_FORMATTER
gl.yformatter = LATITUDE_FORMATTER

# We can set the x and y limits of the plot using ax.set_extent
# This can be used to zoom in and out of particular areas of the map
lon1 = -75.75
lon2 = -73.8
lat1 = 41.5
lat2 = 38.5
extent=[lon1, lon2, lat1, lat2] # Play with this to zoom out enough to provide context
ax.set_extent(extent)

# %% [markdown]
# # Plotting small geographic features

# %% [markdown]
# Adding fine geographic details to a map  While cartopy's stock images and natural features can be helpful for larger maps, sometimes we need to see fine scale detail that isn't included in these datasets. We can plot higher resolution images of terrain on top of our basemap. The existing maps we have been looking at do not have the upstream extent of the Raritan so we can load in a Raritan watershed elevation data product which you will need in your homework and subsequent assignments when making a plot of the Raritan River.

# %%
## Load dataset. The data is located here but we have it downloaded locally for simplicity: https://tds.marine.rutgers.edu/erddap/griddap/RARITAN_ELEVATION.graph
raritan = xr.open_dataset('RARITAN_ELEVATION_f453_6caa_d736.nc')
raritan
# Out:
# <xarray.Dataset>
# Dimensions:    (longitude: 2231, latitude: 2001)
# Coordinates:
#   * longitude  (longitude) float32 -74.56 -74.56 -74.56 ... -74.27 -74.27 -74.27
#   * latitude   (latitude) float32 40.4 40.4 40.4 40.4 ... 40.6 40.6 40.6 40.6
# Data variables:
#     z          (longitude, latitude) float64 ...
# Attributes: (12/26)
#     cdm_data_type:             Grid
#     Conventions:               CF-1.6, COARDS, ACDD-1.3
#     defaultGraphQuery:         z&.draw=surface&.vars=lon,lat,z
#     Easternmost_Easting:       -74.2701
#     geospatial_lat_max:        40.6
#     geospatial_lat_min:        40.4
#     ...                        ...
#     standard_name_vocabulary:  CF Standard Name Table v29
#     Summary:                   This is a synthesized elevation dataset of the...
#     summary:                   This is a synthesized elevation dataset of the...
#     Title:                     Rartian River Basin Elevation Data.
#     title:                     Rartian River Basin Elevation Data.
#     Westernmost_Easting:       -74.56

# %% [markdown]
# ## Adding bathymetry to basemap
# Let's now add this Raritan bathymetry product to our basemap and see what it looks like. We can do that with the plt.contourf() function but because the raritain dataset has latitude, longitude, and depth (i.e. it is spatial data) we need to tell plt.contourf() the map projection.

# %%
fig = plt.figure(figsize=(4,6))
ax = plt.axes(projection = ccrs.PlateCarree())
ax.add_feature(cfeature.OCEAN)
ax.add_feature(cfeature.LAND, edgecolor='black')
ax.add_feature(cfeature.COASTLINE, edgecolor='black')
ax.add_feature(cfeature.STATES, edgecolor='black')

ax.scatter(labs['Longitude'], labs['Latitude'], s=175, c='green',edgecolor='black'); # Plots the individual points on the map

# Also, let's add a title and some information to our axis
plt.title('Key locations for OMDA')
gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True, color='gray', alpha=0.3)
gl.top_labels = False
gl.right_labels = False
gl.xformatter = LONGITUDE_FORMATTER
gl.yformatter = LATITUDE_FORMATTER

# We can set the x and y limits of the plot using ax.set_extent
# This can be used to zoom in and out of particular areas of the map
lon1 = -75.75
lon2 = -73.8
lat1 = 41.5
lat2 = 38.5
extent=[lon1, lon2, lat1, lat2] # Play with this to zoom out enough to provide context
ax.set_extent(extent)

## This is where we add the bathymetry!
bathy = plt.contourf(raritan.longitude, raritan.latitude,raritan.z.transpose(),transform=ccrs.PlateCarree(), cmap='Blues_r')
fig.colorbar(bathy)

# %% [markdown]
# Well that's cool and all but not very information. Let's zoom in with set_extent()

# %%
fig = plt.figure(figsize=(20,10))
ax = plt.axes(projection = ccrs.PlateCarree())
ax.add_feature(cfeature.OCEAN)
ax.add_feature(cfeature.LAND, edgecolor='black')
ax.add_feature(cfeature.COASTLINE, edgecolor='black')
ax.add_feature(cfeature.STATES, edgecolor='black')

ax.scatter(labs['Longitude'], labs['Latitude'], s=175, c='green',edgecolor='black'); # Plots the individual points on the map

# Also, let's add a title and some information to our axis
plt.title('Key locations for OMDA')
gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True, color='gray', alpha=0.3)
gl.top_labels = False
gl.right_labels = False
gl.xformatter = LONGITUDE_FORMATTER
gl.yformatter = LATITUDE_FORMATTER

# We can set the x and y limits of the plot using ax.set_extent
# This can be used to zoom in and out of particular areas of the map
lon1 = -74.5
lon2 = -73.9
lat1 = 40.35
lat2 = 40.6
extent=[lon1, lon2, lat1, lat2] # Play with this to zoom out enough to provide context
ax.set_extent(extent)

bathy = plt.contourf(raritan.longitude, raritan.latitude,raritan.z.transpose(),transform=ccrs.PlateCarree())
fig.colorbar(bathy)

# %% [markdown]
# That's better but now we don't see our important points! We can fix this with zorder. Let's also fix our colorbar ranges with the 'levels' argument in plt.contourf(). Since we can see that there is not very good resolution in the river (but better than cartopy's basemaps) let's ditch the colorbar and only show the extent of the river.

# %%
fig = plt.figure(figsize=(20,10))
ax = plt.axes(projection = ccrs.PlateCarree())
ax.add_feature(cfeature.OCEAN)
ax.add_feature(cfeature.LAND, edgecolor='black')
ax.add_feature(cfeature.COASTLINE, edgecolor='black')
ax.add_feature(cfeature.STATES, edgecolor='black')

ax.scatter(labs['Longitude'], labs['Latitude'], s=175, c='green',edgecolor='black'); # Plots the individual points on the map

# Also, let's add a title and some information to our axis
plt.title('Key locations for OMDA')
gl = ax.gridlines(crs=ccrs.PlateCarree(), draw_labels=True, color='gray', alpha=0.3)
gl.top_labels = False
gl.right_labels = False
gl.xformatter = LONGITUDE_FORMATTER
gl.yformatter = LATITUDE_FORMATTER

# We can set the x and y limits of the plot using ax.set_extent
# This can be used to zoom in and out of particular areas of the map
lon1 = -74.5
lon2 = -73.9
lat1 = 40.35
lat2 = 40.6
extent=[lon1, lon2, lat1, lat2] # Play with this to zoom out enough to provide context
ax.set_extent(extent)

dpth_contours = [ 0]
bathy = plt.contourf(raritan.longitude, raritan.latitude,raritan.z.transpose(),transform=ccrs.PlateCarree(), 
                     cmap='Blues_r', levels=dpth_contours,zorder=0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[77], line 28
#      25 ax.set_extent(extent)
#      27 dpth_contours = [ 0]
# ---> 28 bathy = plt.contourf(raritan.longitude, raritan.latitude,raritan.z.transpose(),transform=ccrs.PlateCarree(),
#      29                      cmap='Blues_r', levels=dpth_contours,zorder=0)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/pyplot.py:2494, in contourf(data, *args, **kwargs)
#    2492 @_copy_docstring_and_deprecators(Axes.contourf)
#    2493 def contourf(*args, data=None, **kwargs):
# -> 2494     __ret = gca().contourf(
#    2495         *args, **({"data": data} if data is not None else {}),
#    2496         **kwargs)
#    2497     if __ret._A is not None: sci(__ret)  # noqa
#    2498     return __ret
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/cartopy/mpl/geoaxes.py:318, in _add_transform.<locals>.wrapper(self, *args, **kwargs)
#     313     raise ValueError(f'Invalid transform: Spherical {func.__name__} '
#     314                      'is not supported - consider using '
#     315                      'PlateCarree/RotatedPole.')
#     317 kwargs['transform'] = transform
# --> 318 return func(self, *args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/cartopy/mpl/geoaxes.py:362, in _add_transform_first.<locals>.wrapper(self, *args, **kwargs)
#     360     # Use the new points as the input arguments
#     361     args = (x, y, z) + args[3:]
# --> 362 return func(self, *args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/cartopy/mpl/geoaxes.py:1714, in GeoAxes.contourf(self, *args, **kwargs)
#    1711             if not hasattr(sub_trans, 'force_path_ccw'):
#    1712                 sub_trans.force_path_ccw = True
# -> 1714 result = matplotlib.axes.Axes.contourf(self, *args, **kwargs)
#    1716 # We need to compute the dataLim correctly for contours.
#    1717 bboxes = [col.get_datalim(self.transData)
#    1718           for col in result.collections
#    1719           if col.get_paths()]
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/__init__.py:1412, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1409 @functools.wraps(func)
#    1410 def inner(ax, *args, data=None, **kwargs):
#    1411     if data is None:
# -> 1412         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1414     bound = new_sig.bind(ax, *args, **kwargs)
#    1415     auto_label = (bound.arguments.get(label_namer)
#    1416                   or bound.kwargs.get(label_namer))
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_axes.py:6313, in Axes.contourf(self, *args, **kwargs)
#    6304 """
#    6305 Plot filled contours.
#    6306
#    (...)
#    6310 %(contour_doc)s
#    6311 """
#    6312 kwargs['filled'] = True
# -> 6313 contours = mcontour.QuadContourSet(self, *args, **kwargs)
#    6314 self._request_autoscale_view()
#    6315 return contours
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/contour.py:812, in ContourSet.__init__(self, ax, levels, filled, linewidths, linestyles, hatches, alpha, origin, extent, cmap, colors, norm, vmin, vmax, extend, antialiased, nchunk, locator, transform, *args, **kwargs)
#     808     self.origin = mpl.rcParams['image.origin']
#     810 self._transform = transform
# --> 812 kwargs = self._process_args(*args, **kwargs)
#     813 self._process_levels()
#     815 self._extend_min = self.extend in ['min', 'both']
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/contour.py:1446, in QuadContourSet._process_args(self, corner_mask, *args, **kwargs)
#    1443     corner_mask = mpl.rcParams['contour.corner_mask']
#    1444 self._corner_mask = corner_mask
# -> 1446 x, y, z = self._contour_args(args, kwargs)
#    1448 _mask = ma.getmask(z)
#    1449 if _mask is ma.nomask or not _mask.any():
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/contour.py:1497, in QuadContourSet._contour_args(self, args, kwargs)
#    1495     _api.warn_external('Log scale: values of z <= 0 have been masked')
#    1496     self.zmin = float(z.min())
# -> 1497 self._process_contour_level_args(args)
#    1498 return (x, y, z)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/contour.py:1191, in ContourSet._process_contour_level_args(self, args)
#    1187         _api.warn_external(
#    1188             "No contour levels were found within the data range.")
#    1190 if self.filled and len(self.levels) < 2:
# -> 1191     raise ValueError("Filled contours require at least 2 levels.")
#    1193 if len(self.levels) > 1 and np.min(np.diff(self.levels)) <= 0.0:
#    1194     raise ValueError("Contour levels must be increasing")
#
# ValueError: Filled contours require at least 2 levels.

# %% [markdown]
# 1. levels determines the depth ranges that are visualized in the contour plot, requiring at least two elements to define at least one range to fill.
# 2. zorder controls the layering of plot elements, with zorder=0 placing the filled contour plot at the base layer so that other elements can be clearly overlaid on top of it.

# %% [markdown]
# # Assignment: Make another high resolution map

# %% [markdown]
# **For this week's assignment, you are going to make just 1 high resolution map.** A map of the Sea Bed Monitoring locations provided by Dave. Bivalves at these sites are monitored monthly to assess their health as they grow!<br><br>
#     - Load in the data from the file `'SBM site coordinates.csv'` using `pandas` and plot every point on the map<br>
#     - Plot the points as dots using `scatter` and color them yellow<br>
#     - Plot the location of the Haskin lab in red and label it in the legend<br>
#     - Plot the map in the PlateCarree projection<br>
#     - Add `OCEAN`, `LAND`, `STATES`, and `COASTLINE` cartopy features<br>
#     - Be sure to include a title and coordinates on the axes<br>
#     - Set the extent for the final map to --> `[-75.6, -74.75, 39.5, 38.6]`<br>
#     - Plot Delaware Bay bathymetry using `plt.contourf()`. I have loaded in this dataset for you in the following cell.<br>
#     - Subset the bathymetry using the latitude and longitude ranges given above. To do this, use the following code: `region = ds_etpo.sel(lon=slice(lon1, lon2), lat=slice(lat1, lat2))`. Then plot `region` using `plt.contourf()`<br>
#     - In `plt.contourf()` set `levels` equal to `np.arange(-34,1,2)` (This is the depth contours to plot/color.<br>
#     - **Bonus:** add a colorbar of the bathymetry. Hint, you will need to define the line of code you use for plotting the bathymetry, something like `bathy=plt.contourf(blah, blah, blah)`<br>

# %%
ds_etpo = xr.open_dataset('bathy_etopo2_v2c.nc')  
ds_etpo
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 5400, lon: 10800)
# Coordinates:
#   * lat      (lat) float32 -89.98 -89.95 -89.92 -89.88 ... 89.92 89.95 89.98
#   * lon      (lon) float32 -180.0 -179.9 -179.9 -179.9 ... 179.9 179.9 180.0
# Data variables:
#     topo     (lat, lon) float64 ...
# Attributes:
#     Conventions:         CF-1.0
#     title:               NGDC ETOPO2v2c Global DEM (2 min))
#     source:              NOAA/NGDC
#     node_offset:         1
#     History:             Translated to CF-1.0 Conventions by Netcdf-Java CDM ...
#     geospatial_lat_min:  -89.98332977294922
#     geospatial_lat_max:  89.98332977294922
#     geospatial_lon_min:  -179.98333740234375
#     geospatial_lon_max:  179.98333740234375
